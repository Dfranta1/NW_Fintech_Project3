# %%
# Import Libraries
import pandas as pd 
import numpy as np 
import yfinance as yf
from datetime import datetime, timedelta

# %% [markdown]
# ### Stock Price Data

# %%
# Get S&P500 symbols ranked by market cap 
sp500_by_marketcap = pd.read_csv('SP500_By_MarketCap.csv')
sp500_by_marketcap.head()
# Out:
#   Symbol                   Name               Industry  \
# 0   AAPL             Apple Inc.  Electronic Technology
# 1   MSFT  Microsoft Corporation    Technology Services
# 2   GOOG          Alphabet Inc.    Technology Services
# 3  GOOGL          Alphabet Inc.    Technology Services
# 4   AMZN       Amazon.com, Inc.           Retail Trade
#
#                Market Cap
# 0   $ 2,986,128,347,290.24
# 1   $ 2,513,296,516,647.36
# 2   $ 1,927,101,773,229.48
# 3   $ 1,923,705,624,039.54
# 4   $ 1,728,404,755,739.39

# %%
# Get tickers in a list
tickers = sp500_by_marketcap['Symbol'].head(50).tolist()
print(tickers)
# Out:
# ['AAPL', 'MSFT', 'GOOG', 'GOOGL', 'AMZN', 'TSLA', 'FB', 'NVDA', 'BRK-B', 'JPM', 'UNH', 'V', 'JNJ', 'HD', 'WMT', 'PG', 'BAC', 'MA', 'PFE', 'DIS', 'AVGO', 'XOM', 'ACN', 'CSCO', 'NFLX', 'NKE', 'LLY', 'KO', 'TMO', 'CRM', 'COST', 'ABT', 'ABBV', 'PEP', 'ORCL', 'CMCSA', 'CVX', 'PYPL', 'DHR', 'VZ', 'INTC', 'QCOM', 'WFC', 'MCD', 'MRK', 'UPS', 'T', 'AMD', 'NEE', 'MS']

# %%
# Set timeframe 
delta = 365
end = datetime.now()
start = datetime.now() - timedelta(delta)

# %%
# Get stock data from yfinance 
df_stock_data=pd.DataFrame()
for ticker in tickers:
    ticker_df = yf.download(ticker, start=start, end=end,interval="1D")
    ticker_df = ticker_df.reset_index()
    ticker_df["Stock"] = ticker
    # Creating a unique key by combining Ticker and Publish date
    ticker_df["unique_key"] = ticker_df["Stock"]+ticker_df["Date"].astype(str)
    df_stock_data =pd.concat([df_stock_data,ticker_df],axis=0)
df_stock_data = df_stock_data.set_index("unique_key")
df_stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                      Date        Open        High         Low       Close  \
# unique_key
# AAPL2021-04-15 2021-04-15  133.820007  135.000000  133.639999  134.500000
# AAPL2021-04-16 2021-04-16  134.300003  134.669998  133.279999  134.160004
# AAPL2021-04-19 2021-04-19  133.509995  135.470001  133.339996  134.839996
# AAPL2021-04-20 2021-04-20  135.020004  135.529999  131.809998  133.110001
# AAPL2021-04-21 2021-04-21  132.360001  133.750000  131.300003  133.500000
#
#                  Adj Close    Volume Stock
# unique_key
# AAPL2021-04-15  133.705322  89347100  AAPL
# AAPL2021-04-16  133.367340  84922400  AAPL
# AAPL2021-04-19  134.043320  94264200  AAPL
# AAPL2021-04-20  132.323532  94812300  AAPL
# AAPL2021-04-21  132.711212  68847100  AAPL

# %%
df_stock_data.to_csv('stock_price_data.csv')
